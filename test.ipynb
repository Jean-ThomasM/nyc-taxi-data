# %%
from datetime import datetime
import pandas as pd

# %%
data = pd.read_parquet("/home/jean-thomas-miquelot/kDrive/PROGRAMMATION/simplon/Simplon_projets/nyc-taxi-data/data/raw/yellow_tripdata_2025-01.parquet")

# %%
import os
os.environ["POSTGRES_HOST"] = "localhost"

# %%
from sqlmodel import Session
from src.database import engine
from src.services import TaxiTripService

with Session(engine) as db:
    print(TaxiTripService.get_trip(db, 1))
# Out:
# 2025-10-22 19:04:22,164 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-10-22 19:04:22,164 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 19:04:22,167 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-10-22 19:04:22,168 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 19:04:22,170 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-10-22 19:04:22,171 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 19:04:22,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
from sqlmodel import Session
from src.database import engine
from src.services import TaxiTripService

with Session(engine) as db:
    print(TaxiTripService.get_trip(db, 1))
    trips, total = TaxiTripService.get_trips(db, skip=0, limit=5)
    print(len(trips), total)
    try:
        stats = TaxiTripService.get_statistics(db)
        print(stats)
    except ValueError as e:
        print("Service a levé ValueError:", e)
# Out:
# 2025-10-22 19:04:23,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
